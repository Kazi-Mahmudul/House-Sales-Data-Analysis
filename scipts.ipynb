# %% [markdown]
# ### Create and Display DataFrame

# %%
import pandas as pd

# load the dataset
df = pd.read_csv("C:/Users/shafi/Downloads/Compressed/House Sales/House Sales/kc_house_data.csv")

# display 10 rows
df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %% [markdown]
# I have imported the pandas library and used read_csv() function of pandas to load the dataset in a Dataframe. Used the df.head(10) function to dsiplay first 10 rows.

# %% [markdown]
# ### Basic information about the Dataset

# %%
# Display column names 
print("Column names:\n", df.columns)
# Out:
# Column names:
#  Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# df.columns is an attribute of pandas which returns the column labels of the DataFrame.

# %%
# Display data types
print("Data types:\n", df.dtypes)
# Out:
# Data types:
#  id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# df.dtypes is an attribute of pandas which returns the data types of the columns.

# %%
# Display non-null counts
print("Non-null values:\n",df.count())
# Out:
# Non-null values:
#  id               21613
# date             21613
# price            21613
# bedrooms         21613
# bathrooms        21613
# sqft_living      21613
# sqft_lot         21613
# floors           21613
# waterfront       21613
# view             21613
# condition        21613
# grade            21613
# sqft_above       21613
# sqft_basement    21613
# yr_built         21613
# yr_renovated     21613
# zipcode          21613
# lat              21613
# long             21613
# sqft_living15    21613
# sqft_lot15       21613
# dtype: int64

# %% [markdown]
# df.count() is a method used to display the non-null values in each columns of a dataframe.

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### Missing Values

# %%
# Find missing values
print(df.isnull().sum())
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# The isnull() method is used to find the null values of the DataFrame and sum() method is used to sum up the null values of each column. The output showing there is no missing value in any column, if I found one I would replace that with the mean value of the particular column.

# %% [markdown]
# #### Duplicate records

# %%
# Find duplicate records
print("Number of duplicate rows:", df.duplicated().sum())

duplicate_id = df['id'].duplicated().sum()
print("Duplicate IDs:", duplicate_id) # 177 duplicate ids has been found
# Out:
# Number of duplicate rows: 0
# Duplicate IDs: 177

# %% [markdown]
# duplicated() is a method used to check duplicate values of a DataFrame. df.duplicated().sum() is used to find the duplicated records of the df DataFrame and sum them up. But no duplicate rows were found. So, I have tried to find duplicate IDs using the same method df['id'].duplicated().sum(), because IDs should not be duplicated, and found 177 duplicates.

# %%
# remove duplicate id
df = df.drop_duplicates(subset=['id'], keep='first')

#confirm remove
print(df['id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# After identifying the duplicates, now it's time to remove them, and for removing duplicates and for removing duplicates drop_duplicates() method is used. df.drop_duplicates(subset=['id'], keep='first'). This code removes the duplicate IDs, subset=['id'] confirms only duplicates from the 'id' column are removed, and keep='first' confirms to keep the first record.

# %% [markdown]
# #### Date-time format conversion

# %%
# convert date column to datetime format
df['date'] = pd.to_datetime(df['date'].str[:8], format='%Y%m%d')

# display the converted date column
print(df['date'].head())
# Out:
# 0   2014-10-13
# 1   2014-12-09
# 2   2015-02-25
# 3   2014-12-09
# 4   2015-02-18
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# In the dataset, the date column has values like '20141013T000000', where the first four digits are the year, the second two digits are the month, and the third two digits are the date. So, we need only eight digits, and the format should be like year-month-date. The to_datetime() method is used to convert the 'date' column to date-time format. The df['date'].str[:8] is used to select only the first 8 digits, and format='%Y%m%d' is used to keep the format year-month-date.

# %% [markdown]
# #### Derived Features

# %% [markdown]
# #### Total area calculation

# %%
# calculate total area
df['total_area'] = df['sqft_living'] + df['sqft_lot']

# display the new column
df[['sqft_living', 'sqft_lot', 'total_area']].head()
# Out:
#    sqft_living  sqft_lot  total_area
# 0         1180      5650        6830
# 1         2570      7242        9812
# 2          770     10000       10770
# 3         1960      5000        6960
# 4         1680      8080        9760

# %% [markdown]
# Total area = df['total_area'] is created by adding Square foot living area = df['sqft_living'] and Square foot lot area = df['sqft_lot']

# %% [markdown]
# #### Property age calculation

# %%
# create year column
df['year'] = df['date'].dt.year

# calculate property age
df['property_age'] = df['year'] - df['yr_built']

# verify property age
df[['year', 'yr_built', 'property_age']].head()
# Out:
#    year  yr_built  property_age
# 0  2014      1955            59
# 1  2014      1951            63
# 2  2015      1933            82
# 3  2014      1965            49
# 4  2015      1987            28

# %% [markdown]
# dt.year is an attribute of Pandas DateTime series that extracts the Year from the date column. df['year'] = df['date'].dt.year does exactly that. Property age is calculated by subtracting the building year df['yr_built'] from the present year df['year'].

# %% [markdown]
# #### Price per square foot calculation

# %%
# calculate price per square fit 
df['price_per_sqft'] = df['price'] / df['total_area'] 

# display the price
df[['price_per_sqft', 'total_area', 'price']].head()
# Out:
#    price_per_sqft  total_area     price
# 0       32.489019        6830  221900.0
# 1       54.830819        9812  538000.0
# 2       16.713092       10770  180000.0
# 3       86.781609        6960  604000.0
# 4       52.254098        9760  510000.0

# %% [markdown]
# Price per square foot df['price_per_sqft'] is calculated by dividing the price df['price'] by the total area df['total_area']. The output seems like total area doesn't really influenced the price per square foot because similar total areas like 6830 and 6960 has different price_per_sqft like 32.48 and 86.78

# %% [markdown]
# #### Floor area calculation

# %%
#calculate the floor area
df['floor_area'] = df['sqft_living'] / df['floors']

#display the number of floors
df[['sqft_living', 'floors', 'floor_area']].head()
# Out:
#    sqft_living  floors  floor_area
# 0         1180     1.0      1180.0
# 1         2570     2.0      1285.0
# 2          770     1.0       770.0
# 3         1960     1.0      1960.0
# 4         1680     1.0      1680.0

# %% [markdown]
# Floor area is calculated to see the area per floor to determine whether it influences the price or not. It is calculated by dividing the living area df['sqft_living'] by floors df['floors']

# %% [markdown]
# #### Renovation age calculation

# %%
#import numpy
import numpy as np

#calculate renovation years using np.where()
df['renovation_year'] = np.where(df['yr_renovated'] > 0, df['year'] - df['yr_renovated'], 0)

#display the column
df[['yr_renovated', 'year', 'renovation_year']].head()
# Out:
#    yr_renovated  year  renovation_year
# 0             0  2014                0
# 1          1991  2014               23
# 2             0  2015                0
# 3             0  2014                0
# 4             0  2015                0

# %% [markdown]
# The renovation age of the houses is calculated by subtracting the year of renovation df['yr_renovated'] from the year df['year']. It is calculated using numpy's where() function, which is based on the condition df['yr_renovated'] > 0.

# %% [markdown]
# #### Outlier identification and handling

# %% [markdown]
# An outlier is a data point that is significantly different from other observations. Detecting and handling outliers is essential in data analysis.

# %% [markdown]
# #### Identification by Z-score

# %%
# Z-score

import numpy as np

# Define function
def detect_outliers(data, threshold = 3 ):
    mean = np.mean(data)
    std = np.std(data)
    z_score = np.abs((data - mean)/ std)   # Z-score formula

    return z_score > threshold

# %% [markdown]
# The Z-score is widely used to method for identifying outliers. It measures how many standand daviations a data point is away from the mean. The formula for Z-score is (data - mean)/std. I defined detect_outlier as a function to detect the outliers. Set threshold=3 means 3rd standard deviation, it returns only that values which are bigger than the threshold.

# %% [markdown]
# #### Price Outlier

# %%
# Price outliers identification
price_outliers = detect_outliers(df['price'])
print(price_outliers.sum())
# Out:
# 403

# %%
# Median price
median_price = np.median(df['price'])

# Set outliers to nan
df.loc[price_outliers, 'price'] = median_price

# %% [markdown]
# #### total_area oulier

# %%
#total_area outliers identification
total_area_outliers = detect_outliers(df['total_area'])
print(total_area_outliers.sum())
# Out:
# 344

# %%
# Median of total_area
median_total_area = np.median(df['total_area'])

# set the outliers to NaN
df.loc[total_area_outliers, 'total_area'] = median_total_area

# %% [markdown]
# #### sqft_living outliers

# %%
# sqft_living outliers identification
sqft_living_outliers = detect_outliers(df['sqft_living'])
print(sqft_living_outliers.sum())
# Out:
# 247

# %%
# Median of sqft_living
median_sqft_living = np.median(df['sqft_living'])

# set the outliers to median
df.loc[sqft_living_outliers, 'sqft_living'] = median_sqft_living

# %% [markdown]
# #### sqft_lot outliers

# %%
# sqft_lot outliers identification
sqft_lot_outliers = detect_outliers(df['sqft_lot'])
print(sqft_lot_outliers.sum())
# Out:
# 343

# %%
# Median of sqft_lot
median_sqft_lot = np.median(df['sqft_lot'])

# set the outliers to median
df.loc[sqft_lot_outliers, 'sqft_lot'] = median_sqft_lot

# %% [markdown]
# #### bedrooms outliers

# %%
# bedrooms outliers identification
bedrooms_outliers = detect_outliers(df['bedrooms'])
print(bedrooms_outliers.sum())
# Out:
# 75

# %%
# Median of bedrooms
median_bedrooms = np.median(df['bedrooms'])

# set the outliers to median
df.loc[bedrooms_outliers, 'bedrooms'] = median_bedrooms

# %% [markdown]
# #### bathrooms outliers

# %%
# bathrooms outliers identification
bathrooms_outliers = detect_outliers(df['bathrooms'])
print(bathrooms_outliers.sum())
# Out:
# 186

# %%
# Median of bathrooms
median_bathrooms = np.median(df['bathrooms'])

# set the outliers to median
df.loc[bathrooms_outliers, 'bathrooms'] = median_bathrooms

# %% [markdown]
# #### floors outliers

# %%
# floors outliers identification
floors_outliers = detect_outliers(df['floors'])
print(floors_outliers.sum())
# Out:
# 8

# %%
# Median of floors
median_floors = np.median(df['floors'])

# set the outliers to median
df.loc[floors_outliers, 'floors'] = median_floors

# %% [markdown]
# #### price_per_sqft outliers

# %%
# price_per_sqft outliers identification
price_per_sqft_outliers = detect_outliers(df['price_per_sqft'])
print(price_per_sqft_outliers.sum())
# Out:
# 377

# %%
# Median of price_per_sqft
median_price_per_sqft = np.median(df['price_per_sqft'])

# set the outliers to median
df.loc[price_per_sqft_outliers, 'price_per_sqft'] = median_price_per_sqft

# %% [markdown]
# #### Grade Outliers

# %%
# grade outliers identification
grade_outliers = detect_outliers(df['grade'])
print(grade_outliers.sum())
# Out:
# 135

# %%
# Median of grade
median_grade = np.median(df['grade'])

# set the outliers to median
df.loc[grade_outliers, 'grade'] = median_grade

# %% [markdown]
# The outliers are identified by using the function detect_outliers(), the features that can have outliers that are used to detect them, like price, total_area, bedrooms, bathrooms, etc. The outliers are handled by replacing the outlier with the median value. The df.loc[] is used to select specific rows and columns to modify them.
# The outputs show that the price column has the most outliers, 403. total_area, price_per_sqft, and sqft_lot have more than 300 outliers each. These outliers could affect our analysis, so they are replaced by their median values.

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# #### Summary Statistics

# %%
# summary statistics for all numerical features
df_specified = df[['price', 'sqft_living', 'sqft_lot', 'total_area', 'sqft_above', 
                         'sqft_basement', 'bedrooms', 'bathrooms', 'floors', 'grade', 'condition',
                         'property_age', 'renovation_year', 'price_per_sqft', 'floor_area']]
df_specified.describe().round(2)
# Out:
#             price  sqft_living   sqft_lot  total_area  sqft_above  \
# count    21436.00     21436.00   21436.00    21436.00    21436.00
# mean    506123.69      2037.70   10893.07    12954.93     1790.96
# std     257190.40       816.82   13739.47    13967.45      829.03
# min      75000.00       290.00     520.00     1423.00      290.00
# 25%     322150.00      1430.00    5040.00     7031.50     1200.00
# 50%     450000.00      1920.00    7614.00     9575.00     1560.00
# 75%     625000.00      2510.00   10330.00    12627.75     2220.00
# max    1640000.00      4830.00  139392.00   141672.00     9410.00
#
#        sqft_basement  bedrooms  bathrooms    floors     grade  condition  \
# count       21436.00  21436.00   21436.00  21436.00  21436.00   21436.00
# mean          291.74      3.36       2.09      1.50      7.64       3.41
# std           442.78      0.87       0.72      0.54      1.12       0.65
# min             0.00      1.00       0.00      1.00      5.00       1.00
# ...

# %% [markdown]
# df_specified is created to select the important features of the dataset. describe() method summarized all the features and gave information about count, mean, std, etc of the features. From the output we can see the features are consistent.

# %% [markdown]
# #### Distribution of price using histogram

# %%
#import matplotlib and seaborn
import seaborn as sns
import matplotlib.pyplot as plt

# Plot histogram
plt.figure(figsize=(10, 5))
sns.histplot(x=df['price'], bins=40, kde=True)
plt.title("Distribution of House Prices")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Histogram is used to visualize the distribution of house prices, it shows whether the price is normally distributed or skewed. KDE curve provides a smooth estimation of the price.
# sns.histplot(x=df['price'], bins=40, kde=True) draws histogram from seaborn library, bins=40 divides the price range to 40 intervals and kde=True adds a KDE curve to show the probability distribution.
# The histogram shows that the price is mostly distributed from 200k to 600k, which means most people prefer to buy houses in this price range.

# %% [markdown]
# #### Relationships between house prices and key features

# %% [markdown]
# #### Price by Total Area

# %%
# Define custom bins and labels
bins = [0, 2000, 4000, 6000, 8000, 10000, df['total_area'].max()]
labels = ['<2000', '2000-4000', '4000-6000', '6000-8000', '8000-10000', '10000+']

# Create a new column for area categories
df['area_group'] = pd.cut(df['total_area'], bins=bins, labels=labels)

# %% [markdown]
# The total area is divided into some groups by their area size to smoothly visualize their relationship with the price.
# pd.cut() method is used to cut the columns is different groups according to the bins.

# %%
# Display average price by total area
plt.figure(figsize=(10,5))
df.groupby('area_group')['price'].mean().plot(kind='bar', edgecolor='black')
plt.title('Average Price by Total Area')
plt.xlabel('Total Area')
plt.ylabel('Average Price')
plt.xticks(rotation=0)
plt.show()
# Out:
# C:\Users\shafi\AppData\Local\Temp\ipykernel_5924\2678608346.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('area_group')['price'].mean().plot(kind='bar', edgecolor='black')

# %% [markdown]
# df.groupby('area_group')['price'].mean() groups the dataset by area group and calculates the average price for each group. plot(kind='bar') creates bar chart where x axis has area_group and y axis has average price.
# The output shows that the area group 6000-8000 sqft has the maximum average price, while group 8000-10000 has more area but a lower average price. Seems like 6000 to 8000 sqft areas are more demanding.

# %% [markdown]
# #### Price by bedroom count

# %%
# Display average price by bedroom count
plt.figure(figsize=(10, 5))
df.groupby('bedrooms')['price'].mean().plot(kind='bar', edgecolor='black')
plt.title("Average House Price by Number of Bedrooms")
plt.xlabel("Number of Bedrooms")
plt.ylabel("Average Price")
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# df.groupby('bedrooms')['price'].mean() groups the dataset by bedrooms and calculates the average price for each group. plot(kind='bar') creates bar chart where x axis has bedrooms and y axis has average price.
# The output shows that the average price is increasing almost linearly with the number of bedrooms.

# %% [markdown]
# #### Price by floor count

# %%
# Display average price by floors count
plt.figure(figsize=(10, 5))
df.groupby('floors')['price'].mean().plot(kind='bar', edgecolor='black')
plt.title("Average House Price by Number of floors")
plt.xlabel("Number of floors")
plt.ylabel("Average Price")
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# df.groupby('floors')['price'].mean() groups the dataset by floors and calculates the average price for each group. plot(kind='bar') creates bar chart where x axis has bedrooms and y axis has average price.
# The output shows that the average price is increasing almost linearly with the number of bedrooms, but the houses with 3 floors has a lower average price than the houses with 2.5 floors.

# %% [markdown]
# #### Time Trend in House Price

# %%
# Extract months from the date column
df['month'] = df['date'].dt.month

df['month'].head()
# Out:
# 0    10
# 1    12
# 2     2
# 3    12
# 4     2
# Name: month, dtype: int32

# %% [markdown]
# dt.month used to extract month from date column

# %%
# Create year_month column
df['year_month'] = df['year'].astype(str) + '-' + df['month'].astype(str).str.zfill(2)

# %% [markdown]
# df['year_month'] is created by concatenate year and month columns. astype(str) used to convert the columns to string and zfill(2) is used fill the months with 2 digits, like converting the month '2' to '02'.

# %%
df['year_month'].head()
# Out:
# 0    2014-10
# 1    2014-12
# 2    2015-02
# 3    2014-12
# 4    2015-02
# Name: year_month, dtype: object

# %%
# Group by year_month 
price_trend = df.groupby('year_month')['price'].mean().reset_index()

# Display the price trend
plt.figure(figsize=(10, 5))
sns.lineplot(data=price_trend, x='year_month', y='price', marker='o')
plt.xticks(rotation = 45)
plt.title('House Price Trend Over Time')
plt.xlabel('Year_Month')
plt.ylabel('Average Price')
plt.show()

# %% [markdown]
# price_trend = df.groupby('year_month')['price'].mean().reset_index() groups the dataset by year_month and calculates the average price for each month. reset_index() ensures that the grouped data is converted back into a DataFrame. Lineplot from seaborn is chosen as the visualizer of the time trend. Output shows that the price trend was in decreasing order until February 2015, but then it got a hike for two months, and again decreased in May.

# %% [markdown]
# #### Correlation between numeric columns using heatmap

# %%
# Selected columns for correlation matrix
correlation_matrix = df[['price', 'sqft_living', 'sqft_lot', 'total_area', 'sqft_above', 
                         'sqft_basement', 'bedrooms', 'bathrooms', 'floors', 'grade', 'condition',
                         'property_age', 'renovation_year', 'price_per_sqft', 'floor_area']].corr()

# plot heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5, fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# A Heatmap is used to define the correlation between numerical columns of a dataset. df[['price', 'sqft_living', '...']].corr() calculates the correlation coefficients between the selected numerical features. Correlation values range from -1 to 1. sns.heatmap() is used to plot the heatmap of the correlation matrix, and annot=True is used to display the correlation values inside the heatmap cells. In our output, we can see some highly correlated features with the values of 0.78, 0.70, 0.68, etc. There are also some negative values like -0.40, -0.39, etc, which indicate that if one variable increases, the other decreases.

# %% [markdown]
# #### Features influence the price most

# %%
# sort the price correlation in descending order
price_corr = correlation_matrix['price'].sort_values(ascending=False)
# Round the values
price_rounded = price_corr.round(2)
print(price_rounded)
# Out:
# price              1.00
# grade              0.62
# sqft_living        0.60
# sqft_above         0.51
# bathrooms          0.46
# price_per_sqft     0.40
# floor_area         0.35
# bedrooms           0.31
# floors             0.27
# sqft_basement      0.26
# total_area         0.15
# sqft_lot           0.11
# renovation_year    0.05
# condition          0.03
# property_age      -0.06
# Name: price, dtype: float64

# %% [markdown]
# correlation_matrix['price'].sort_values(ascending=False) is used to sort the price correlation with other features in a descending order

# %%
# Plot the price correlation
plt.figure(figsize=(20, 5))
sns.barplot(x=price_rounded.index, y=price_rounded.values)
plt.title('Correlation of features with House Price')
plt.xlabel('Features')
plt.ylabel('Correlation with price')
plt.show()

# %% [markdown]
# A bar chart is used to plot the output of price correlation with other features, where the x-axis has the indexes and the y-axis has the values of the price correlation. The output shows that price is highly affected by the grade and sqft_living, which means that a higher grade, sqft_living result in  a higher price. On the other hand, property age is inversely correlated, which means that price decreases when the property age increases.

# %% [markdown]
# #### Features influence the grade most

# %%
# Sort the grade correlation in descending order
grade_corr = correlation_matrix['grade'].sort_values(ascending=False)
# Rounded values
grade_corr_rounded = grade_corr.round(2)
print(grade_corr_rounded)
# Out:
# grade              1.00
# sqft_above         0.70
# sqft_living        0.70
# bathrooms          0.63
# price              0.62
# floors             0.46
# bedrooms           0.36
# floor_area         0.33
# price_per_sqft     0.21
# total_area         0.19
# sqft_lot           0.15
# sqft_basement      0.14
# renovation_year   -0.03
# condition         -0.15
# property_age      -0.45
# Name: grade, dtype: float64

# %% [markdown]
# grade_corr = correlation_matrix['grade'].sort_values(ascending=False) is used to sort the grade correlation with other features in a descending order.

# %%
# Display the grade correlations
plt.figure(figsize=(20, 5))
sns.barplot(x=grade_corr_rounded.index, y=grade_corr_rounded.values)
plt.title('Correlation of features with grade')
plt.xlabel('Features')
plt.ylabel('Correlation with grade')
plt.show()

# %% [markdown]
# A bar chart is used to plot the output of grade correlation with other features, where the x-axis has the indexes and the y-axis has the values of the grade correlation. The output shows that grade is highly affected by the sqft_above and sqft_living, which means that higher sqft_above, sqft_living have a higher grade. On the other hand, property age, renovation year are inversely correlated which means grade decreases when the property age, renovation age increases.

# %% [markdown]
# ### Basic Statistical Analysis

# %% [markdown]
# #### Calculate Mean, Median and Mode

# %%
# Mean
price_mean = df['price'].mean()
total_area_mean = df['total_area'].mean()

# Median
price_median = df['price'].median()
total_area_median = df['total_area'].median()

# Mode
price_mode = df['price'].mode()[0]
total_area_mode = df['total_area'].mode()[0]

# Display the results
print(f"Mean Price: {price_mean: ,.2f}, Median Price: {price_median: ,.2f}, Mode Price: {price_mode: .2f}")
print()
print(f"Mean Total Area: {total_area_mean: ,.2f}, Median Total Area: {total_area_median: ,.2f}, Mode Total Area: {total_area_mode: .2f}")
# Out:
# Mean Price:  506,123.69, Median Price:  450,000.00, Mode Price:  450000.00
#
# Mean Total Area:  12,954.93, Median Total Area:  9,575.00, Mode Total Area:  9575.00

# %% [markdown]
# mean(), median(), and mode() methods are used to calculate the mean, median, and modes of the price and total_area. mode()[0] is used to select the first mode if there a multiple modes accured. The output shows median and mode are similar in both cases but the mean is different from them.

# %% [markdown]
# #### Perform a T-Test

# %% [markdown]
# A t-test is a statistical test used to campare the mean of two groups and determine if the differences between them are statistically significant.

# %% [markdown]
# #### Price difference based on bedrooms

# %%
from  scipy.stats import ttest_ind

# Create two groups of bedrooms
group1 = df[df['bedrooms'] <= 3]['price']
group2 = df[df['bedrooms'] > 3]['price']

# Perform t-test
t_stat, p_value = ttest_ind(group1, group2, equal_var=False)

# Display results
print(f"t-stat: {t_stat: .4f}, p_value: {p_value: .4f}")

# Condition
if p_value < 0.05:
    print("Significant difference in price based on bedrooms")
else:
    print("No significant difference in price based on bedrooms")
# Out:
# t-stat: -44.2552, p_value:  0.0000
# Significant difference in price based on bedrooms

# %% [markdown]
# This code is used to perform the t-test to determine the significant difference in price based on homes with <=3 and >3 bedrooms. ttest_ind() method is used to find the t-statistics and p_value of the two groups but the output shows the p_value is 0 which is extremely low.

# %%
import numpy as np

# Cohen's d function
def cohen_d(group1, group2):
    mean_diff = np.mean(group1) - np.mean(group2)
    std_pool = np.sqrt((np.std(group1, ddof=1)**2 + np.std(group2, ddof=1)**2)/2)
    return mean_diff / std_pool

# Create two groups of bedrooms
group1 = df[df['bedrooms'] <= 3]['price']
group2 = df[df['bedrooms'] > 3]['price']

# d_value
d_value = cohen_d(group1, group2)
print(f"Cohen's d: {d_value: .3f}")

if abs(d_value) >= 0.5:
    print("Moderate effect")
elif abs(d_value) >= 0.3:
    print("Small effect")
else:
    print("High effect")
# Out:
# Cohen's d: -0.632
# Moderate effect

# %% [markdown]
# Because previously the p_value was 0, that's why I apply Cohen's d to measure effect size, to determine the magnitude of differences between the two groups. It is measured by dividing the mean differences by the pooled standard deviation. I applied some conditions to measure the effect size, and the output shows they have a moderate effect based on the conditions.

# %% [markdown]
# #### Price difference based on total area

# %%
# Create two groups of total area
smaller_area = df[df['total_area'] < total_area_median]['price']
larger_area = df[df['total_area'] > total_area_median]['price']

# Perform t-test
t_stat, p_value = ttest_ind(smaller_area, larger_area, equal_var=False)

# Display results
print(f"T_stat: {t_stat: .4f}, p_value: {p_value: .4f}")

#Condition
if p_value < 0.05:
    print("Significant difference in price based on total area")
else:
    print("No significant difference in price based on total area")
# Out:
# T_stat: -20.2817, p_value:  0.0000
# Significant difference in price based on total area

# %% [markdown]
# This code is used to perform the t-test to determine the significant difference in price based on total areas with smaller and larger areas. ttest_ind() method is used to find the t-statistics and p_value of the two groups but the output shows the p_value is 0 which is extremely low.

# %%
# Cohen's d function for areas
area_d_value = cohen_d(smaller_area, larger_area)

# Cohen's d value for areas
print(f"Cohen's d: {area_d_value: .3f}")

# Conditions
if abs(area_d_value) >= 0.5:
    print("Moderate effect")
elif abs(area_d_value) >= 0.3:
    print("Small effect")
else:
    print("High effect")
# Out:
# Cohen's d: -0.280
# High effect

# %% [markdown]
# Because previously the p_value was 0, that's why I apply Cohen's d to measure effect size, to determine the magnitude of differences between the two groups. It is measured by dividing the mean differences by the pooled standard deviation. I applied some conditions to measure the effect size, and the output shows they have a high effect based on the conditions.

# %% [markdown]
# #### House price distribution by grade

# %%
# Boxplot for the distribution
plt.figure(figsize=(10, 5))
sns.boxplot(x=df['grade'], y=df['price'], legend=False, hue=df['grade'], palette='coolwarm')
plt.title("House Price Distribution by Grade")
plt.xlabel("House Grade")
plt.ylabel("Price")
plt.grid(True)
plt.show()

# %% [markdown]
# This code is used to create a boxplot to visualize the distribution of house prices based on different grades. sns.boxplot() creates a boxplot where the x-axis has the grade and the y-axis has the price. legend=False disables the legends because it's not necessary here. hue=df['grade'] this groups the boxplot by the house grade.

# %% [markdown]
# #### Usage of AI and Search Engines

# %% [markdown]
# In this assignment, I have used different AI tools like ChatGPT, ClaudeAI, Perplexity, and search engines like Google and Bing to clarify concepts and explain complex methods like t-test, Cohen's d, and troubleshooting the issues encountered during the process. YouTube videos, Wikipedia, and research papers also helped me to understand some topics. I used these tools to understand some crucial topics, then I applied them myself. Overall, these tools were a helpful assistant, but I had to do most of the work myself.
